# %% [markdown]
# Importing Neccessary libraries

# %%
#Importing Neccessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st

# %%
#load the data
df = pd.read_csv("metadata.csv")

# Display the first few rows of the dataframe

df.head()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_15804\1513293731.py:2: DtypeWarning: Columns (1,4,5,6,13,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("metadata.csv")
#    cord_uid                                       sha source_x  \
# 0  ug7v899j  d1aafb70c066a2068b02786f8929fd9c900897fb      PMC
# 1  02tnwd4m  6b0567729c2143a66d737eb0a2f63f2dce2e5a7d      PMC
# 2  ejv2xln0  06ced00a5fc04215949aa72528f2eeaae1d58927      PMC
# 3  2b73a28n  348055649b6b8cf2b9a376498df9bf41f7123605      PMC
# 4  9785vg6d  5f48792a5fa08bed9f56016f4981ae2ca6031b32      PMC
#
#                                                title                    doi  \
# 0  Clinical features of culture-proven Mycoplasma...  10.1186/1471-2334-1-6
# 1  Nitric oxide: a pro-inflammatory mediator in l...           10.1186/rr14
# 2    Surfactant protein-D and pulmonary host defense           10.1186/rr19
# ...

# %%
#Check the DataFrame dimensions
df.shape
# Out:
# (1056660, 19)

# %%
#Identify data types of each column
df.dtypes
# Out:
# cord_uid             object
# sha                  object
# source_x             object
# title                object
# doi                  object
# pmcid                object
# pubmed_id            object
# license              object
# abstract             object
# publish_time         object
# authors              object
# journal              object
# mag_id              float64
# who_covidence_id     object
# arxiv_id             object
# pdf_json_files       object
# pmc_json_files       object
# url                  object
# s2_id               float64
# dtype: object

# %%
#Check for missing values in important columns
df.isnull().sum()
# Out:
# cord_uid                  0
# sha                  682894
# source_x                  0
# title                   503
# doi                  399880
# pmcid                667089
# pubmed_id            557728
# license                   0
# abstract             235544
# publish_time           1814
# authors               23869
# journal               87322
# mag_id              1056660
# who_covidence_id     573725
# arxiv_id            1042411
# pdf_json_files       682894
# pmc_json_files       740918
# url                  369726
# s2_id                 80192
# dtype: int64

# %%
df.isnull().sum()# Filling missing values
df.fillna(method='ffill', inplace=True)  # Forward fill to handle missing values
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_15804\748866349.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)  # Forward fill to handle missing values

# %%
# Filling missing values 
df.isna().sum()
# Out:
# cord_uid                  0
# sha                       0
# source_x                  0
# title                     0
# doi                       0
# pmcid                     0
# pubmed_id                 0
# license                   0
# abstract                  0
# publish_time              0
# authors                   0
# journal                   0
# mag_id              1056660
# who_covidence_id     193989
# arxiv_id             193993
# pdf_json_files            0
# pmc_json_files            0
# url                       0
# s2_id                 79535
# dtype: int64

# %%
df.fillna(method='ffill', inplace=True)  # Forward fill to handle missing values
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_15804\1633339965.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)  # Forward fill to handle missing values

# %%
# Filling missing values 
df.isna().sum()
# Out:
# cord_uid                  0
# sha                       0
# source_x                  0
# title                     0
# doi                       0
# pmcid                     0
# pubmed_id                 0
# license                   0
# abstract                  0
# publish_time              0
# authors                   0
# journal                   0
# mag_id              1056660
# who_covidence_id     193989
# arxiv_id             193993
# pdf_json_files            0
# pmc_json_files            0
# url                       0
# s2_id                 79535
# dtype: int64

# %%
#saving a clean file
df.to_csv("cleaned_metadata.csv", index=False)

# %%
#Convert date columns to datetime format
df['publish_time'] = pd.to_datetime(df['publish_time'], errors='coerce')

# %%
#checking for data types
df.dtypes
# Out:
# cord_uid                    object
# sha                         object
# source_x                    object
# title                       object
# doi                         object
# pmcid                       object
# pubmed_id                   object
# license                     object
# abstract                    object
# publish_time        datetime64[ns]
# authors                     object
# journal                     object
# mag_id                     float64
# who_covidence_id            object
# arxiv_id                    object
# pdf_json_files              object
# pmc_json_files              object
# url                         object
# s2_id                      float64
# dtype: object

# %%
#Extract year from publication date for time-based analysis
df['publish_year'] = df['publish_time'].dt.year

# %% [markdown]
# Basic analysis

# %%
#Count papers by publication year
yearly_counts = df['publish_year'].value_counts().sort_index()
print(yearly_counts)
# Out:
# publish_year
# 1856.0         3
# 1857.0         1
# 1860.0         2
# 1864.0         1
# 1876.0         1
#            ...
# 2020.0    164787
# 2021.0    219642
# 2022.0     85395
# 2023.0         1
# 2024.0         1
# Name: count, Length: 75, dtype: int64

# %%
#Identify top journals publishing COVID-19 research
top_journals = df['journal'].value_counts().head(10)
print(top_journals)
# Out:
# journal
# bioRxiv                            10642
# PLoS One                           10579
# Int J Environ Res Public Health     8505
# BMJ                                 7385
# Sci Rep                             6316
# Cureus                              4465
# Sustainability                      4005
# Reactions Weekly                    3936
# Front Psychol                       3756
# BMJ Open                            3739
# Name: count, dtype: int64

# %%
#Find most frequent words in titles (using simple word frequency)
from collections import Counter
import re   
all_titles = ' '.join(df['title'].dropna().astype(str)).lower()
words = re.findall(r'\b\w+\b', all_titles)
word_counts = Counter(words)
most_common_words = word_counts.most_common(10)
print(most_common_words)
# Out:
# [('of', 719955), ('the', 561889), ('and', 542143), ('in', 529458), ('covid', 494964), ('19', 484626), ('a', 349922), ('for', 207511), ('to', 170548), ('with', 163257)]

# %%
#Create visualizations
#Papers published per year
plt.figure(figsize=(20,6))
sns.barplot(x=yearly_counts.index, y=yearly_counts.values, palette='viridis')
plt.title('Papers Published Per Year')
plt.xlabel('Year')
plt.ylabel('Number of Papers')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_15804\2801386587.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=yearly_counts.index, y=yearly_counts.values, palette='viridis')

# %%
#Plot number of publications over time
plt.figure(figsize=(20,6))
df['publish_time'].value_counts().sort_index().plot()
plt.title('Publications Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Publications')
plt.show()

# %%
#Create a bar chart of top publishing journals
plt.figure(figsize=(10,6))
sns.barplot(x=top_journals.values, y=top_journals.index, palette='magma')
plt.title('Top 10 Journals Publishing COVID-19 Research')
plt.xlabel('Number of Papers')
plt.ylabel('Journal')
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_15804\3375609703.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_journals.values, y=top_journals.index, palette='magma')

# %%
#Generate a word cloud of paper titles
from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_titles)
plt.figure(figsize=(10,5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#Plot distribution of paper counts by source
plt.figure(figsize=(10,20))
sns.countplot(y='source_x', data=df, order=df['source_x'].value_counts().index)
plt.title('Distribution of Paper Counts by Source')
plt.xlabel('Number of Papers')
plt.ylabel('Source')
plt.show()

# %%
#Build a simple Streamlit app
st.title("COVID-19 Research Papers Analysis")
st.write("This app analyzes a dataset of COVID-19 research papers.")
#Identify top journals publishing COVID-19 research
top_journals = df['journal'].value_counts().head(10)
# Out:
# 2025-09-29 08:41:19.214 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 08:41:19.216 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 08:41:19.219 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 08:41:19.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 08:41:19.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 08:41:19.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#Create a basic layout with title and description
st.title("COVID-19 Research Papers Analysis")
st.write("This app analyzes a dataset of COVID-19 research papers.")
# Out:
# 2025-09-29 08:41:39.896 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 08:41:39.899 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 08:41:39.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 08:41:39.906 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 08:41:39.910 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 08:41:39.913 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#Add interactive widgets (sliders, dropdowns)
year_filter = st.slider("Select Publication Year", int(df['publish_year'].min()), int(df['publish_year'].max()), (2020, 2022))
# Out:
# 2025-09-29 08:42:21.033 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 08:42:21.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 08:42:21.037 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 08:42:21.044 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 08:42:21.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-29 08:42:21.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#Display your visualizations in the app

# %%
#Show a sample of the data
